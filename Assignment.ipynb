# %% [markdown]
# <a href="https://colab.research.google.com/github/meghanjukl-meg/ICTK_Assignment/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Bank Account Manager

# %%
class Bank_Account:
    def __init__(self):

        self.balance = 0

    def deposit(self):
        amount = float(input("Enter amount to be deposited :"))
        self.balance += amount
        print(f"Successfully deposited Rs.{amount}")

    def withdraw(self):
        amount = float(input("Enter amount to withdraw"))
        if amount <= self.balance:
            self.balance -= amount
            print(f"you have successfully withdrawn Rs.{amount}")
        else:
            print("Not enough money to withdraw")

    def balance_check(self):
        print(f"Available Balance = {self.balance}")


account_no = 45678
account_number = int(input("Enter account number :"))
if account_number== account_no:
    print("choose your type of transaction:/n"
          "1.Deposit"
          "2.Withdrawal"
          "3.Check Balance/n")
    option=int(input("Enter your choice 1/2/3: "))

    account = Bank_Account()
    if option == 1:
        account.deposit()
    elif option ==2:
        account.withdraw()
    else:
        account.balance_check()
else:
    print("Invalid Account Number")
# Out:
# Enter account number :45678
# choose your type of transaction:/n1.Deposit2.Withdrawal3.Check Balance/n
# Enter your choice 1/2/3: 1
# Enter amount to be deposited :1000
# Successfully deposited Rs.1000.0

# %%
account.deposit()
# Out:
# Enter amount to be deposited :500
# Successfully deposited Rs.500.0

# %%
account.withdraw()
# Out:
# Enter amount to withdraw1000
# you have successfully withdrawn Rs.1000.0

# %%
account.balance_check()
# Out:
# Available Balance = 500.0

# %%
account.withdraw()
# Out:
# Enter amount to withdraw600
# Not enough money to withdraw

# %% [markdown]
# #2.WeatherDataAnalyzer

# %% [markdown]
# ## To determine weather conditions

# %%
def weather_condition(temp,humidity):

  if temp >= 25 :
    if humidity >= 70:
      condition="Rainy"
    elif 70 > humidity >= 40:
      condition = "Warm"
    else :
      condition = "Sunny/Hot"

  elif 25 > temp >= 15:
    if humidity >=70:
      condition = "Cloudy"
    else:
      condition = "Pleasent"

  elif 15 > temp >= 0:
    if humidity >= 70:
      condition = "Cold with Fog"
    else:
      condition = "Cold"
  else:
    condition = "Snowy"

  return condition

# %%
temperature = float(input("Enter the temperature for given region (in Celsius) : "))
humidity = float(input("Enter the humidity for given region (in percentage): "))
weather = weather_condition(temperature,humidity)
print(f"The weather condition is :{weather}")
# Out:
# Enter the temperature for given region (in Celsius) : 23
# Enter the humidity for given region (in percentage): 75
# The weather condition is :Cloudy

# %% [markdown]
# ## To calculate average temperature and humidity

# %%
temp_list = [23,23.7,24,24.8,25,24.6]
humidity_list=[75,79,80,84,82,81]

# %%
def avg_temp(temp):
    total = sum(temp)
    avg = total/len(temp)
    return avg
def avg_humidity(humidity):
    total = sum(humidity)
    avg = total/len(humidity)
    return avg

average_temperature = avg_temp(temp_list)
average_humidity = avg_humidity(humidity_list)

# %%
print(f"Average temperature : {average_temperature} Celsius")
print(f"Average humidity: {average_humidity} %")
# Out:
# Average temperature : 24.183333333333334 Celsius
# Average humidity: 80.16666666666667 %
